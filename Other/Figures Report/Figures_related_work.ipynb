# %% [markdown]
# **Import Libraries**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Plot Training Augmentations from Papers**

# %%
augmentations = ['Normalize', 'Resize', 'Resize + CenterCrop', 'HorizontalFlip', 'Rotation','RandAug']
num_augmentations = [7, 5, 2, 3, 3, 1]

# Plot
plt.bar(augmentations, num_augmentations, color='deepskyblue')
plt.xticks(rotation=45, ha='right')
plt.show()
